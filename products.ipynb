# %%
products = [] 

while True:
    p = input( 'Enter product name:')
    products.append(p)
    print('product added')
    print(products)
    Q = input('Do you want to continue? yes/no')
    if Q=='no':
              print('Thank you for using the app')
              break
# Out:
# Enter product name: tecno
# product added
# ['tecno']
# Do you want to continue? yes/no no
# Thank you for using the app

# %%
# Guess Game
import random
score = 0 

live = 5
player = input( 'Enter your name:')
print(f'Hi, {player}. Welcome to playstation!')
while true 
    if live == 0:
    print ('Game over')
    breAK

# %%
#write a program to create students profile

profile = {
    'firstname': 'Enitan',
     'lastname': 'emeka',
    'age': 20,
    'address': {
        'state': 'Lagos',
        'country': 'Nigeria',
        'LGA': 'Bariga'
    },
    'matricno': 'F/ND/24/3450043'
}

# %%
profile
# Out:
# {'firstname': 'Enitan',
#  'lastname': 'emeka',
#  'age': 20,
#  'address': {'state': 'Lagos', 'country': ['Canada'], 'LGA': 'Bariga'},
#  'matricno': 'F/ND/24/3450043'}

# %%
profile ['address']['country']
# Out:
# ['Canada']

# %%
profile['address']['country']=['Canada']

# %%
profile['address']['state']
# Out:
# 'Lagos'

# %%
profile['firstname']
# Out:
# 'Enitan'

# %%
profile['age']
# Out:
# 20
